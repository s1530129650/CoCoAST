# %%
import pickle

# %%
data = pickle.load(open("split_AST.pkl","rb"))

# %%
data[4270]
# Out:
# {4270: [['ROOT', ['METHOD_SIGNATURWE', ['METHOD_BODY', ['STATEMENTS_BLOCK']]]],
#   ['METHOD_SIGNATURWE',
#    ['MODIFIER', ['override'], ['public']],
#    ['RETURN', ['int']],
#    ['NAME', ['run'], ['command']],
#    ['PARAMS',
#     ['VAR',
#      ['TYPE', ['boolean']],
#      ['NAME', ['merge'], ['error'], ['into'], ['output']]],
#     ['VAR', ['TYPE', ['string']], ['NAME', ['commands']]]]],
#   ['STATEMENTS_BLOCK',
#    ['STMT',
#     ['return'],
#     ['run'],
#     ['command'],
#     ['('],
#     ['merge'],
#     ['error'],
#     ['into'],
#     ['output'],
#     [','],
#     ['new'],
#     ['array'],
#     ['list'],
#     ['<'],
#     ['string'],
#     ['>'],
#     ['('],
#     ['arrays'],
#     ['as'],
#     ['list'],
#     ['('],
#     ['commands'],
#     [')'],
#     [')'],
#     [')'],
#     [';']]]],
#  65622: [['ROOT',
#    ['METHOD_SIGNATURWE',
#     ['METHOD_BODY',
#      ['STATEMENTS_BLOCK'],
#      ['IF'],
#      ['IF'],
#      ['STATEMENTS_BLOCK'],
#      ['TRY'],
# ...

# %%
data[4270]
# Out:
# [['ROOT', ['METHOD_SIGNATURWE', ['METHOD_BODY', ['STATEMENTS_BLOCK']]]],
#  ['METHOD_SIGNATURWE',
#   ['MODIFIER', ['override'], ['public']],
#   ['RETURN', ['int']],
#   ['NAME', ['run'], ['command']],
#   ['PARAMS',
#    ['VAR',
#     ['TYPE', ['boolean']],
#     ['NAME', ['merge'], ['error'], ['into'], ['output']]],
#    ['VAR', ['TYPE', ['string']], ['NAME', ['commands']]]]],
#  ['STATEMENTS_BLOCK',
#   ['STMT',
#    ['return'],
#    ['run'],
#    ['command'],
#    ['('],
#    ['merge'],
#    ['error'],
#    ['into'],
#    ['output'],
#    [','],
#    ['new'],
#    ['array'],
#    ['list'],
#    ['<'],
#    ['string'],
#    ['>'],
#    ['('],
#    ['arrays'],
#    ['as'],
#    ['list'],
#    ['('],
#    ['commands'],
#    [')'],
#    [')'],
#    [')'],
#    [';']]]]
